# %% [markdown]
# ## **VEŽBA**
# U jednoj osnovnoj školi, u toku je akcija sakupljanja plastičnih čepova. U datom nizu **cepovi** se nalaze podaci o broju čepova koji su sakupljeni po danima. Vaš zadatak je da na osnovu tog niza uradite sledeću analizu:

# %%
cepovi=[47,32,51,87,12,64,9,78,54,22,48,93]

# %% [markdown]
# •	Broj dana koliko je trajalo sakupljanje čepova.
#
# •	Najveći broj sakupljenih čepova u nekom danu.
#
# •	Najmanji broj sakupljenih čepova u nekom danu.
#
# •	Ukupan broj sakupljenih čepova.
#
# •	Prosečan broj sakupljenih čepova.
#
# •	Utvrditi da li je broj sakupljenih čepova veći od 450. Ukoliko jeste, napisati poruku **BRAVO**, ukoliko nije, napisati poruku **MOŽEŠ TI TO  BOLJE**
#
# •	Sortirati niz **cepovi** od najmanjeg do najvećeg broja.
#
# •	U novi niz koji ćeš nazvati **velikiCepovi** ostaviti samo one dane u kojima su sakupljani čepovi iznad 40.

# %% [markdown]
# ![vf.png](attachment:fec92fb6-9ffd-4553-9fd3-0a14690b3c81.png)

# %% [markdown]
# ![sort.png](attachment:c9f71988-db5a-4902-b3dd-5a4d7060d175.png)

# %% [markdown]
# Za filtriranje niza u Python-u se može upotrebiti sledeća konstrukcija:

# %% [markdown]
# ![naredba filtriranje.png](attachment:36ec4368-3e09-4af4-9d3d-6376d6d1a12f.png)
