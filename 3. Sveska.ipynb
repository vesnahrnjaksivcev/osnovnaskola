# %% [markdown]
# ## **Nizovi podataka**
# **<font color= red >Nizovi podataka</font>** se u Pajtonu zapisuju unutar uglastih zagrada, u obliku liste. Na primer,ocene nekog učenika iz jednog predmeta mogu da se zapišu kao niz ovako:

# %%
ocene=[2,4,3,5,3]       # niz podataka, u ovom slučaju ocene
ocene                   # navođenjem imena promenljive i pokretanjem RUN dobićemo prikaz niza
len(ocene)              # navođenjem funkcije len(promenljiva)izračunaže se broj elemenata u nizu

# %% [markdown]
# **<font color= red >Napomena:</font>** obrati pažnju na komentare na slici.
#
# **<font color= red >Napomena:</font>**  Ugličaste zagrade **<font color= red >[ ]</font>** se pozivaju u Džupiteru sa **<font color= red >desni ALT i slovo F istovremeno </font>** (za otvaranje zagrade) i **<font color= red >desni ALT i slovo G istovremeno </font>** (za zatvaranje zagrade).
#
# **<font color= red >Napomena:</font>**  funkcija **<font color= red >len(ime_promenljive)</font>**  služi za izračunavanje broja elemenata u nizu podataka.

# %%
predmeti=["matematika", "srpski", "likovno", "istorija", "informatika", "geografija"]       
len(predmeti)

# %% [markdown]
# ![vf.png](attachment:fec92fb6-9ffd-4553-9fd3-0a14690b3c81.png)

# %% [markdown]
# ### **Zadatak 1.**
# Za navedene maksimalne dnevne temperature u toku 10 dana aprila izračunati maksimalnu, minimalnu i prosečnu temperaturu.

# %%
temperature=[19,22,26,20,22,20,21,14,19,20]

# %% [markdown]
# ### **Zadatak 2.**
# Napravi niz donacije u kojem će biti sačuvani iznosi uplaćeni tokom jedne humanitarne
# akcije, zatim odredi ukupan broj uplata, najmanji i najveći iznos uplate, prosečnu vrednost
# svih uplata, kao i ukupan iznos sakupljen tokom humanitarne akcije.

# %%
donacije=[5700,2500,3000,1200,400,2500,1800,900,1500,4300]

# %% [markdown]
# ### **Zadatak 3.**
# U okviru istraživanja, meren je dnevni nivo buke u dvorištu osnovne škole tokom godinu dana. Nivo buke u području škole ne bi trebalo da prelazi 50dB. U tabeli su dati prosečni rezultati merenja po mesecima.

# %% [markdown]
# ![buka.png](attachment:330f895f-849c-4bb9-a930-c13f1d527cba.png)

# %% [markdown]
# a)	U kojem se intervalu nalaze izmerene vrednosti?
#
# b)	Kolika je bila prosečna vrednost nivoa buke?
#
# c)	Da li prosečna vrednost prelazi preporučenu granicu od 50dB?

# %%
buka=[52.2,55.7,57.5,47.3,60.2,49.5,51.5,48.9,53.1,51.2,50.4,48.6]

# %% [markdown]
# a) Interval u kojem se nalaze izmerene vrednosti dobiće se određivanjem najmanjeg i najvećeg elementa u nizu.

# %% [markdown]
# b) Određivanje prosečne vrednosti nivoa buke. Prvo uvodimo promenljivu prosek i dodeljujemo joj funkciju, zatim  tu promenljivu definišemo kroz print i zaokružujemo je funkcijom round na dva decimalna mesta.

# %% [markdown]
# c) Promenljivu prosek ćemo upotrebiti u naredbi if za ispisivanje odgovarajuće poruke.
