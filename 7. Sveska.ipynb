# %% [markdown]
# **<font color= red > Osvrt na grafičko predstavljanje – linijski grafikon (zadaci za vežbu).</font>**

# %% [markdown]
# **Zadatak 1**
#
# U narednoj ćeliji dati su podaci o masi (u kilogramima) i dužini/visini (u centimetrima) jednog dečaka od njegovog šestog meseca pa do njegovih 6,5 godina.

# %%
merenja   = ["6 mes", "1,5 god", "2,5 god", "3,5 god", "4,5 god", "5,5 god", "6,5 god"]
masaKG    = [5.9,     11.5,      14.8,      20.5,      22.0,      24.2,      29.0]
visinaCM  = [62.0,    84.0,      97.0,      115.0,     122.5,     131.5,     135.0 ]

# %% [markdown]
#  Pre svega je potrebno iznad prvog reda ukucati naredbu:
# **import matplotlib.pyplot as plt**
# kako bi se pokrenula biblioteka za rad sa grafikonima. Ovu ćeliju očitati sa naredbom **RUN**.

# %% [markdown]
# a)	Prikaži linijskim grafikonom kako se menjala njegova masa.

# %% [markdown]
# b)	Prikaži linijskim grafikonom kako se menjala njegova visina.

# %% [markdown]
# c)	Za dečaka iz ovog zadatka prikaži grafikonom promenu njegovog indeksa telesne težine. Može ti pomoći sledeći mali Pajton program koji računa njegove indekse telesne težine za svako merenje.
# **Objašnjenje:** BMI (indeks telesne mase), je visinsko-težinski pokazatelj uhranjenostu neke osobe. U medicini se koristi za definisanje gojaznosti. BMI omogućava da se uporedi stepen uhranjenosti sa stepenom rizika obolevanja od pojedinih oboljenja.
#
# ![bmi.png](attachment:53e38b95-0836-440d-9353-c6ff1033adb0.png)

# %% [markdown]
# **Zadatak 2**
#
# Procenjuje se da je Kina na dan 1.7.2019. imala 1.420.062.022 stanovnika. Broj stanovnika u Kini se svake godine poveća za 0,35%. Pod pretpostavkom da se godišnji rast broja stanovnika u Kini neće menjati, prikazati grafikonom očekivani broj stanovnika Kine u narednih deset godina.

# %% [markdown]
# **Zadatak 3**
#
# Svaka država ima organizovanu službu koja pažljivo beleži podatke o vremenskim prilikama zato što je to važno za saobraćaj, poljoprivredu, ali i sve ostale privredne grane.
# Na sajtu Republičkog hidrometeorološkog zavoda Srbije ( http://www.hidmet.gov.rs/ ) u meniju sa leve strane klikni na "Meteorologija", pa "Klimatologija", pa na "Normale". Potom u spisku stanica za osmatranje koji se pojavio odaberi stanicu najbližu tvojoj školi, preuzmi najniže i najviše temperature u periodu 1981-2010 (redovi "Apsolutni maksimum" i "Apsolutni minimum") i prikaži te podatke.

# %%
meseci= ["Jan", "Feb", "Mar", "Apr", "Maj", "Jun", "Jul", "Avg", "Sep", "Okt", "Nov", "Dec"]
apsolutnimaksimum=[ 17.1, 20.4, 26.3,30.4, 33.7,37.5, 40.0,38.9,37.4, 28.8,24.3,19.7]
apsolutniminimum=[ -27.0, -24.5, -14.8, -5.9, 1.7, 4.7, 7.1, 6.5, 2.2, -7.7, -13.8, -22.4]
