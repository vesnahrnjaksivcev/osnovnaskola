# %% [markdown]
# ## **Upoznavanje sa radom u Jyputer-u (radno okruženje)**

# %% [markdown]
# Svaka Džupiter radna sveska se sastoji iz niza ćelija, a svaka ćelija može da sadrži tekst, matematički izraz ili niz Pajton naredbi.
# U ovoj lekciji ćemo se upoznati kroz rad sa osnovama rada u ovom okruženju.

# %% [markdown]
# U Džupiteru možemo da izračunavamo **<font color= red > aritmetičke operacije </font>**:

# %%
3+12

# %%
15-3

# %%
15//7        #celobrojno delenje

# %%
15%7         #ostatak pri delenju

# %%
a=15
b=7
c=a/b

# %%
import math        #importujemo, tj. pozivamo biblioteku math

# %%
round (c,2)       # naredba za zaokruživanje broja na 2 decimalna mesta

# %%
math.ceil (c)      # naredba za zaokruživanje broja na prvi veći broj

# %%
math.floor (c)    # naredba za zaokruživanje broja na prvi veći broj

# %% [markdown]
# ### <b>1.	Zadatak

# %% [markdown]
# Napisati program za izračunavanje zbira dva cela broja koja se unose sa tastature.

# %% [markdown]
# **Napomena:**
# Kada završite sa definisanjem promenljivih i otkucate komandu print, izvršenje morate potvrditi sa **RUN**. Nakon što unesete prvi broj, pritisnite ENTER na tastaturi,  isto to uradite i nakon drugog unetog broja kako bi vam se pokazalo rešenje.

# %% [markdown]
# ### <b>2.	Zadatak

# %% [markdown]
# Za dati dvocifreni broj ispisati broj cifara i najveću cifru.

# %% [markdown]
# ### <b>3.	Zadatak

# %% [markdown]
# Izračunati obim, površinu i dijagonala pravougaonika čije su stranice a i b.

# %% [markdown]
# **Napomena:**
# * 	Naredba za kvadratni koren je math.sqrt ()  - podsećanje
# * 	Naredba za stepenovanje, na primer a2 ćemo zapisati kao a zatim ** i broj stepena, tj. a**2 – podsećanje

# %% [markdown]
# ### <b>4.	Zadatak

# %% [markdown]
# Na slici je prikazano nekoliko ostrva. Tačkama A, B i C označene su luke, a linijama trase kojima plove brodovi od luke do luke.

# %% [markdown]
# ![Ship.png](attachment:450e94fc-8b3d-4771-a02c-2a8b6de327d7.png)

# %% [markdown]
# 1. Korišćenjem operatora za stepenovanje i funkcije iz biblioteke **math** izračunaj najkraće rastojanje od luke A do luke B.
