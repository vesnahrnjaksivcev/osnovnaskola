# %% [markdown]
# **<font color= red >FILTRIRANJE</font>**

# %% [markdown]
# **Filtrirati** podatke znači iz datog niza podataka izdvojiti one koji su nam na neki način interesantni.
# Postupak izdvajanja podataka koji odgovaraju nekom kriterijumu naziva se filtriranje podataka.
#
# U programu Microsoft Excel smo učili da filtriranje podrazumeva izdvajanje određenih redova koji ispunjavaju određeni kriterijum i sakrivanje ostalih redova.
#
# U programskom jeziku Python, u postupku filtriranja podataka iz niza ne vrši se sakrivanje suvišnih podataka, nego se izdvajaju podaci koji ispunjavaju neki uslov.
#
# Izdvojeni podaci se mogu ispisati na izlazu ili se mogu sačuvati kao novi niz podataka radi daljeg korišćenja u analizi i obradi.
#
# Za filtriranje niza u Python-u se može upotrebiti sledeća konstrukcija

# %% [markdown]
# ![naredba filtriranje.png](attachment:36ec4368-3e09-4af4-9d3d-6376d6d1a12f.png)

# %% [markdown]
# Ova konstrukcija u novi niz pokupi sve elemente **<font color= red >i</font>** niza **<font color= red >ImeNiza</font>** koji ispunjavaju **<font color= red >Uslov</font>**.

# %% [markdown]
# **Primer:**
# Iz niza u kojem su zabeležene uplate tokom humanitarne akcije mogu se izdvojiti iznosi koji su veći od neke granice (na primer veći do 2000 dinara).

# %%
donacije=[5000,2500,3000,1200,500,2500,1800,900,1500,4300,5640,870,1400,800,3000,2400,1000,500,800,650]

# %% [markdown]
# Ukoliko nam je važno da se nastavi sa izdvojenim podacima, treba ih sačuvati u novom nizu.  Novom nizu možemo izbrojati elemente primenjujući funkciju **<font color= red >len(velikeUplate)</font>**.

# %% [markdown]
# **Zadatak 1.**
#
# Za niz koji sadrži broj izostanaka svih učenika u odeljenjunapiši naredbe koje će:
#
# •	izračunati i ispisati ukupan broj izostanaka u odeljenju,
#
# •	izdvojiti i ispisati koliko učenika ima više od 50 izostanaka,
#
# •	izdvojiti i ispisati izostanke učenika manje od 10 i
#
# •	napisati koliko ima učenika bez ijednog izostanka.

# %% [markdown]
# **Rešenje:**
# 1.	Uvođenjem nove promenljive **<font color= red >ukupno</font>** izračunaćemo ukupan broj izostanaka kroz funkciju **<font color= red >sum</font>** i zatim ćemo taj broj ispisati kroz funkciju **<font color= red >print</font>** .

# %%
izostanci=[28,26,66,7,0,17,43,9,45,14,10,77,105,30,43,37,66,11,20,15,30,46,27,16,13]

# %% [markdown]
# 2.	Brojeve učenika sa više od 50 izostanaka ćemo sačuvati u novoj promenljivoj **<font color= red >viseOd50</font>** i nakon toga ćemo funkcijom **<font color= red >len</font>** izračunati koliko ima učenika sa više od 50 izostanaka. Taj podatak ćemo ispisati pomoću funkcije **<font color= red >print</font>**.

# %% [markdown]
# 3.	Na sličan način se izdvajaju izostanci koji su manji od 50.

# %% [markdown]
# 4.	Kod određivanja broja učenika bez izostanaka potrebno je izdvojiti elemente koji su jednaki nuli pomoću uslova **<font color= red >i==0</font>**, a zatim pomoću funkcije **<font color= red >len</font>** odrediti broj izdvojenih elemenata.

# %% [markdown]
# **Zadatak 2**
#
# U tabeli su dati rezultati takmičenja iz programiranja.

# %% [markdown]
# ![tabela.png](attachment:f2bf40db-147a-43d0-a46e-9f85654da259.png)

# %% [markdown]
# Za osvajanje nagrade i prelazak na sledeći nivo takmičenja je potrebano da takmičar osvoji 60 i više bodova.
# U novoj radnoj svesci pronađi odgovore na sledeća pitanja:
#
# •	Koliki je prosečan broj bodova?
#
# •	Koliko je takmičara koji su osvojili dovoljan broj bodova za prelazak na sledeći nivo?
#
# •	Kako bi izgledao niz bodova sortiran opadajuće?
#
# •	Koliko se takmičara plasiralo na sledeći nivo takmičenja nakon što se organizatori svima dodelili po sedam nagradnih bodova?
#
# •	Navedi koliko bodova imaju prvoplasirani, drugoplasirani i trećeplasirani takmičar.

# %% [markdown]
# **Rešenje:**
#
# Pre svega je potrebno kreirati niz:

# %%
bodovi=[52,46,17,75,58,40,65,30,50,25]

# %% [markdown]
# 1.	Izračunavanje prosečne vrednosti niza. Može se prvo uvesti promenljiva **<font color= red >prosek</font>** koja će predstavljati izračunavanje prosečne vrednosti i zatim se pozvati prilikom ispisa pomoću funkcije **<font color= red >print</font>**.

# %% [markdown]
# 2.	Bodovi koji su veći ili jednaki sa 60 se izdvajaju u poseban niz **<font color= red >iznad60</font>** , a zatim se sa funkcijom **<font color= red >len</font>** određuje njihova dužina. Novi niz će predstavljati broj takmičara koji imaju dovoljan broj za prelezak na sledeći nivo takmičenja.

# %% [markdown]
# 3.	Sortiranje koje će nam omogućiti da se sortirani elementi mogu koristiti i u nastavku rada sa podacima je **<font color= red >bodovi.sort(reverse=True)</font>** .

# %% [markdown]
# 4.	Formiranje novog niza bodova uvećanih za 7 nagradnih bodova. Novi niz se može nazvati **<font color= red >bodoviUvecani</font>**.

# %% [markdown]
# Pre svega, potrebno je kreirati novi niz i nazvati ga recimo **<font color= red >iznad60Novi</font>** koji će predstavljati niz prethodnih bodova koji su uvećani za 7 i iz tog novog niza pozivom funkcije **<font color= red >len</font>** odrediti broj elemenata niza koji su veći od 60. Pozivom funkcije **<font color= red >len</font>** može se videti da je sada broj učenika koji ispunjavaju uslov za plasiranje na viši nivo takmičenja 3.

# %% [markdown]
# 5.	Za ispis prva tri elementa niza koristićemo navođenje imena niza  i pozicije elemenata. Indeksiranje niza počinje od nule. Tako da se na poziciji 0 nalaze bodobi prvoplasiranog (tj. najveći element niza), na poziciji 1 se nalaze bodovi drugoplasiranog, dok se na poziciji 2 nalaze bodovi trećeplasiranog takmičara.
